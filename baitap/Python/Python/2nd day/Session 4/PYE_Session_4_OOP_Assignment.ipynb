# %% [markdown]
# # Câu 1: Object oriented programming with python

# %% [markdown]
# Cho class diagram sau:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Triển khai diagram trên với ngôn ngữ python.
# - Khai báo các class bao gồm các thuộc tính và hành vi của mỗi đối tượng.
# - Thực hiện khởi tạo một vài ví dụ

# %% [markdown]
# # Câu 2: Object-relational mapping (ORM)

# %% [markdown]
# Cho đối tượng Bài viết với các thuộc tính sau:
# - Tiêu đề
# - Tác giả
# - Tóm tắt
# - Nội dung
# - Ngày xuất bản

# %% [markdown]
# Thực hiện tạo class ORM cho đối tượng trên và thực hiện một số nghiệm vụ sao:
# - Thêm 5 bài viết database `baiviet.db`
# - Xử dụng .get() và .select() để lấy ra một số đối tượng mong muốn
